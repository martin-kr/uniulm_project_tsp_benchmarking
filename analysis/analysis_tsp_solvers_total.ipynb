# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
exclude_pla33810 = True

# %%
# Define size
size = '01_small'

# Define file names
if size == '01_small':
    nn = 'benchmark_solver_nn.2025-02-19_10-40-53.results'
    two_opt = 'benchmark_solver_2opt.2025-02-19_10-55-52.results'
    two_approx = 'benchmark_solver_2appox.2025-02-19_10-48-21.results'
    christ = 'benchmark_solver_christofides.2025-02-19_10-54-26.results'
elif size == '02_medium':
    nn = 'benchmark_solver_nn.2025-02-19_11-19-06.results'
    two_opt = 'benchmark_solver_2opt.2025-02-19_11-22-26.results'
    two_approx = 'benchmark_solver_2approx.2025-02-19_11-20-23.results'
    christ = 'benchmark_solver_christofides.2025-02-19_11-23-17.results'
elif size == '03_large':
    nn = 'benchmark_solver_nn.2025-02-19_11-36-08.results'
    two_opt = 'benchmark_solver_2opt.2025-02-19_12-01-00.results'
    two_approx = 'benchmark_solver_2approx.2025-02-19_11-42-25.results'
    christ = 'benchmark_solver_christofides.2025-02-19_13-13-20.results'

# Define the base path
base_path = f'/Users/martin/uniUlm/3.Semester/themen_software_engineering/hausarbeit/uniulm_project_tsp_benchmarking/benchexec/{size}/results/'
column_names = ['problem', 'status', 'cputime', 'walltime', 'memory']

# Get values for solvers
small_df_solver_nn = pd.read_csv(f'{base_path}{nn}.csv', sep='\t', skiprows=2, names=column_names)
small_df_solver_nn = small_df_solver_nn.drop(0)

small_df_solver_2opt = pd.read_csv(f'{base_path}{two_opt}.csv', sep='\t', skiprows=2, names=column_names)
small_df_solver_2opt = small_df_solver_2opt.drop(0)

small_df_solver_2approx = pd.read_csv(f'{base_path}{two_approx}.csv', sep='\t', skiprows=2, names=column_names)
small_df_solver_2approx = small_df_solver_2approx.drop(0)

small_df_solver_christ = pd.read_csv(f'{base_path}{christ}.csv', sep='\t', skiprows=2, names=column_names)
small_df_solver_christ = small_df_solver_christ.drop(0)

# Get poblem instances and their numeric values
def extract_number(problem_name):
    match = re.search(r'\d+', problem_name)
    return int(match.group()) if match else None

small_solver_instances = small_df_solver_nn.problem.array
small_solver_instances_num = small_df_solver_nn.problem.apply(extract_number).to_numpy()

# %%
# Define size
size = '02_medium'

# Define file names
if size == '01_small':
    nn = 'benchmark_solver_nn.2025-02-19_10-40-53.results'
    two_opt = 'benchmark_solver_2opt.2025-02-19_10-55-52.results'
    two_approx = 'benchmark_solver_2appox.2025-02-19_10-48-21.results'
    christ = 'benchmark_solver_christofides.2025-02-19_10-54-26.results'
elif size == '02_medium':
    nn = 'benchmark_solver_nn.2025-02-19_11-19-06.results'
    two_opt = 'benchmark_solver_2opt.2025-02-19_11-22-26.results'
    two_approx = 'benchmark_solver_2approx.2025-02-19_11-20-23.results'
    christ = 'benchmark_solver_christofides.2025-02-19_11-23-17.results'
elif size == '03_large':
    nn = 'benchmark_solver_nn.2025-02-19_11-36-08.results'
    two_opt = 'benchmark_solver_2opt.2025-02-19_12-01-00.results'
    two_approx = 'benchmark_solver_2approx.2025-02-19_11-42-25.results'
    christ = 'benchmark_solver_christofides.2025-02-19_13-13-20.results'

# Define the base path
base_path = f'/Users/martin/uniUlm/3.Semester/themen_software_engineering/hausarbeit/uniulm_project_tsp_benchmarking/benchexec/{size}/results/'
column_names = ['problem', 'status', 'cputime', 'walltime', 'memory']

# Get values for solvers
medium_df_solver_nn = pd.read_csv(f'{base_path}{nn}.csv', sep='\t', skiprows=2, names=column_names)
medium_df_solver_nn = medium_df_solver_nn.drop(0)

medium_df_solver_2opt = pd.read_csv(f'{base_path}{two_opt}.csv', sep='\t', skiprows=2, names=column_names)
medium_df_solver_2opt = medium_df_solver_2opt.drop(0)

medium_df_solver_2approx = pd.read_csv(f'{base_path}{two_approx}.csv', sep='\t', skiprows=2, names=column_names)
medium_df_solver_2approx = medium_df_solver_2approx.drop(0)

medium_df_solver_christ = pd.read_csv(f'{base_path}{christ}.csv', sep='\t', skiprows=2, names=column_names)
medium_df_solver_christ = medium_df_solver_christ.drop(0)

# Get poblem instances and their numeric values
def extract_number(problem_name):
    match = re.search(r'\d+', problem_name)
    return int(match.group()) if match else None

medium_solver_instances = medium_df_solver_nn.problem.array
medium_solver_instances_num = medium_df_solver_nn.problem.apply(extract_number).to_numpy()

# %%
# Define size
size = '03_large'

# Define file names
if size == '01_small':
    nn = 'benchmark_solver_nn.2025-02-19_10-40-53.results'
    two_opt = 'benchmark_solver_2opt.2025-02-19_10-55-52.results'
    two_approx = 'benchmark_solver_2appox.2025-02-19_10-48-21.results'
    christ = 'benchmark_solver_christofides.2025-02-19_10-54-26.results'
elif size == '02_medium':
    nn = 'benchmark_solver_nn.2025-02-19_11-19-06.results'
    two_opt = 'benchmark_solver_2opt.2025-02-19_11-22-26.results'
    two_approx = 'benchmark_solver_2approx.2025-02-19_11-20-23.results'
    christ = 'benchmark_solver_christofides.2025-02-19_11-23-17.results'
elif size == '03_large':
    nn = 'benchmark_solver_nn.2025-02-19_11-36-08.results'
    two_opt = 'benchmark_solver_2opt.2025-02-19_12-01-00.results'
    two_approx = 'benchmark_solver_2approx.2025-02-19_11-42-25.results'
    christ = 'benchmark_solver_christofides.2025-02-19_13-13-20.results'

# Define the base path
base_path = f'/Users/martin/uniUlm/3.Semester/themen_software_engineering/hausarbeit/uniulm_project_tsp_benchmarking/benchexec/{size}/results/'
column_names = ['problem', 'status', 'cputime', 'walltime', 'memory']

# Get values for solvers
large_df_solver_nn = pd.read_csv(f'{base_path}{nn}.csv', sep='\t', skiprows=2, names=column_names)
large_df_solver_nn = large_df_solver_nn.drop(0)

large_df_solver_2opt = pd.read_csv(f'{base_path}{two_opt}.csv', sep='\t', skiprows=2, names=column_names)
large_df_solver_2opt = large_df_solver_2opt.drop(0)

large_df_solver_2approx = pd.read_csv(f'{base_path}{two_approx}.csv', sep='\t', skiprows=2, names=column_names)
large_df_solver_2approx = large_df_solver_2approx.drop(0)

large_df_solver_christ = pd.read_csv(f'{base_path}{christ}.csv', sep='\t', skiprows=2, names=column_names)
large_df_solver_christ = large_df_solver_christ.drop(0)

if exclude_pla33810:
    large_df_solver_nn = large_df_solver_nn.drop(10)
    large_df_solver_2opt = large_df_solver_2opt.drop(10)
    large_df_solver_2approx = large_df_solver_2approx.drop(10)
    large_df_solver_christ = large_df_solver_christ.drop(10)
    

# Get poblem instances and their numeric values
def extract_number(problem_name):
    match = re.search(r'\d+', problem_name)
    return int(match.group()) if match else None

large_solver_instances = large_df_solver_nn.problem.array
large_solver_instances_num = large_df_solver_nn.problem.apply(extract_number).to_numpy()

# %%
large_solver_instances_num
# Out:
# array([ 2319,  3038,  3795,  4461,  5915,  7397, 11849, 14051, 18512])

# %%
large_df_solver_2approx
# Out:
#         problem status      cputime            walltime       memory
# 1     u2319.tsp   done    2.5304284  2.5408012379994034    56.336384
# 2   pcb3038.tsp   done    4.4283607  4.4032045639996795   108.257280
# 3    fl3795.tsp   done   10.7634608  10.796855992000019   107.728896
# 4   fnl4461.tsp   done    9.0356521    9.13648189199921   209.195008
# 5    rl5915.tsp   done   16.8984974  16.898020887000712   409.337856
# 6   pla7397.tsp   done   35.5876353   35.64411400899917   410.509312
# 7   rl11849.tsp   done   68.5694376   68.86111149299995  1620.463616
# 8  brd14051.tsp   done  182.9370124  183.36230603500007  1620.078592
# 9    d18512.tsp   done  170.5291625  171.42712072500035  3234.947072

# %%
# Combine to one df

df_solver_nn = pd.concat([small_df_solver_nn, medium_df_solver_nn, large_df_solver_nn], ignore_index=True)
df_solver_2opt = pd.concat([small_df_solver_2opt, medium_df_solver_2opt, large_df_solver_2opt], ignore_index=True)
df_solver_2approx = pd.concat([small_df_solver_2approx, medium_df_solver_2approx, large_df_solver_2approx], ignore_index=True)
df_solver_christ = pd.concat([small_df_solver_christ, medium_df_solver_christ, large_df_solver_christ], ignore_index=True)

# Get poblem instances and their numeric values
def extract_number(problem_name):
    match = re.search(r'\d+', problem_name)
    return int(match.group()) if match else None

solver_instances = df_solver_nn.problem.array
solver_instances_num = df_solver_nn.problem.apply(extract_number).to_numpy()

# %%
# nn
solver_nn_runtime_cpu_string = df_solver_nn.cputime.array
solver_nn_runtime_cpu = pd.to_numeric(solver_nn_runtime_cpu_string)

solver_nn_runtime_wall_string = df_solver_nn.walltime.array
solver_nn_runtime_wall = pd.to_numeric(solver_nn_runtime_wall_string)

solver_nn_memory_string = df_solver_nn.memory.array
solver_nn_memory = pd.to_numeric(solver_nn_memory_string)

df_solver_nn_status_success = df_solver_nn[df_solver_nn['status'] != 'ABORTED']
df_solver_nn_status_aborted = df_solver_nn[df_solver_nn['status'] == 'ABORTED']

solver_nn_success = df_solver_nn_status_success.problem.array
solver_nn_success_num = df_solver_nn_status_success.problem.apply(extract_number).to_numpy()
solver_nn_aborted = df_solver_nn_status_aborted.problem.array
solver_nn_aborted_num = df_solver_nn_status_aborted.problem.apply(extract_number).to_numpy()
solver_nn_status = df_solver_nn.status.array

# 2-opt
solver_2opt_runtime_cpu_string = df_solver_2opt.cputime.array
solver_2opt_runtime_cpu = pd.to_numeric(solver_2opt_runtime_cpu_string)

solver_2opt_runtime_wall_string = df_solver_2opt.walltime.array
solver_2opt_runtime_wall = pd.to_numeric(solver_2opt_runtime_wall_string)

solver_2opt_memory_string = df_solver_2opt.memory.array
solver_2opt_memory = pd.to_numeric(solver_2opt_memory_string)

df_solver_2opt_status_success = df_solver_2opt[df_solver_2opt['status'] != 'ABORTED']
df_solver_2opt_status_aborted = df_solver_2opt[df_solver_2opt['status'] == 'ABORTED']

solver_2opt_success = df_solver_2opt_status_success.problem.array
solver_2opt_success_num = df_solver_2opt_status_success.problem.apply(extract_number).to_numpy()
solver_2opt_aborted = df_solver_2opt_status_aborted.problem.array
solver_2opt_aborted_num = df_solver_2opt_status_aborted.problem.apply(extract_number).to_numpy()
solver_2opt_status = df_solver_2opt.status.array

# 2-approx
solver_2approx_runtime_cpu_string = df_solver_2approx.cputime.array
solver_2approx_runtime_cpu = pd.to_numeric(solver_2approx_runtime_cpu_string)

solver_2approx_runtime_wall_string = df_solver_2approx.walltime.array
solver_2approx_runtime_wall = pd.to_numeric(solver_2approx_runtime_wall_string)

solver_2approx_memory_string = df_solver_2approx.memory.array
solver_2approx_memory = pd.to_numeric(solver_2approx_memory_string)

df_solver_2approx_status_success = df_solver_2approx[df_solver_2approx['status'] != 'ABORTED']
df_solver_2approx_status_aborted = df_solver_2approx[df_solver_2approx['status'] == 'ABORTED']

solver_2approx_success = df_solver_2approx_status_success.problem.array
solver_2approx_success_num = df_solver_2approx_status_success.problem.apply(extract_number).to_numpy()
solver_2approx_aborted = df_solver_2approx_status_aborted.problem.array
solver_2approx_aborted_num = df_solver_2approx_status_aborted.problem.apply(extract_number).to_numpy()
solver_2approx_status = df_solver_2approx.status.array

# christ
solver_christ_runtime_cpu_string = df_solver_christ.cputime.array
solver_christ_runtime_cpu = pd.to_numeric(solver_christ_runtime_cpu_string)

solver_christ_runtime_wall_string = df_solver_christ.walltime.array
solver_christ_runtime_wall = pd.to_numeric(solver_christ_runtime_wall_string)

solver_christ_memory_string = df_solver_christ.memory.array
solver_christ_memory = pd.to_numeric(solver_christ_memory_string)

df_solver_christ_status_success = df_solver_christ[df_solver_christ['status'] != 'ABORTED']
df_solver_christ_status_aborted = df_solver_christ[df_solver_christ['status'] == 'ABORTED']

solver_christ_success = df_solver_christ_status_success.problem.array
solver_christ_success_num = df_solver_christ_status_success.problem.apply(extract_number).to_numpy()
solver_christ_aborted = df_solver_christ_status_aborted.problem.array
solver_christ_aborted_num = df_solver_christ_status_aborted.problem.apply(extract_number).to_numpy()
solver_christ_status = df_solver_christ.status.array

# %%
# Scatter plot for better visualization
plt.figure(figsize=(12, 6))
# plt.scatter(solver_instances_num, solver_nn_runtime_cpu, color='k', label='NN', zorder=3, marker='^')
# plt.scatter(solver_instances_num, solver_2opt_runtime_cpu, color='b', label='2-Opt', zorder=3, marker='^')
# plt.scatter(solver_instances_num, solver_2approx_runtime_cpu, color='r', label='2-Approx', zorder=3, marker='^')
# plt.scatter(solver_instances_num, solver_christ_runtime_cpu, color='g', label='Christofides', zorder=3, marker='^')


# NN
# Plot completed instances
completed_indices = [i for i in range(len(solver_nn_status)) if solver_nn_status[i] == 'done']
plt.scatter(
    [solver_instances_num[i] for i in completed_indices],
    [solver_nn_runtime_cpu[i] for i in completed_indices],
    color='k', label='NN (done)', zorder=3, marker='^'
)

# Plot aborted instances
aborted_indices = [i for i in range(len(solver_nn_status)) if solver_nn_status[i] == 'ABORTED']
plt.scatter(
    [solver_instances_num[i] for i in aborted_indices],
    [solver_nn_runtime_cpu[i] for i in aborted_indices],
    color='k', label='NN (aborted)', zorder=3, marker='x'
)


# 2-Opt
# Plot completed instances
completed_indices = [i for i in range(len(solver_2opt_status)) if solver_2opt_status[i] == 'done']
plt.scatter(
    [solver_instances_num[i] for i in completed_indices],
    [solver_2opt_runtime_cpu[i] for i in completed_indices],
    color='b', label='2-Opt (done)', zorder=3, marker='^'
)

# Plot aborted instances
aborted_indices = [i for i in range(len(solver_2opt_status)) if solver_2opt_status[i] == 'ABORTED']
plt.scatter(
    [solver_instances_num[i] for i in aborted_indices],
    [solver_2opt_runtime_cpu[i] for i in aborted_indices],
    color='b', label='2-Opt (aborted)', zorder=3, marker='x'
)


# 2-Approx
# Plot completed instances
completed_indices = [i for i in range(len(solver_2approx_status)) if solver_2approx_status[i] == 'done']
plt.scatter(
    [solver_instances_num[i] for i in completed_indices],
    [solver_2approx_runtime_cpu[i] for i in completed_indices],
    color='r', label='2-Approx (done)', zorder=3, marker='^'
)

# Plot aborted instances
aborted_indices = [i for i in range(len(solver_2approx_status)) if solver_2approx_status[i] == 'ABORTED']
plt.scatter(
    [solver_instances_num[i] for i in aborted_indices],
    [solver_2approx_runtime_cpu[i] for i in aborted_indices],
    color='r', label='2-Approx (aborted)', zorder=3, marker='x'
)


# Christofides
# Plot completed instances
completed_indices = [i for i in range(len(solver_christ_status)) if solver_christ_status[i] == 'done']
plt.scatter(
    [solver_instances_num[i] for i in completed_indices],
    [solver_christ_runtime_cpu[i] for i in completed_indices],
    color='g', label='Christofides (done)', zorder=3, marker='^'
)

# Plot aborted instances
aborted_indices = [i for i in range(len(solver_christ_status)) if solver_christ_status[i] == 'ABORTED']
plt.scatter(
    [solver_instances_num[i] for i in aborted_indices],
    [solver_christ_runtime_cpu[i] for i in aborted_indices],
    color='g', label='Christofides (aborted)', zorder=3, marker='x'
)


plt.plot(solver_instances_num, solver_nn_runtime_cpu, linestyle='-', color='k', alpha=0.5, zorder=2)
plt.plot(solver_instances_num, solver_2opt_runtime_cpu, linestyle='-', color='b', alpha=0.5, zorder=2)
plt.plot(solver_instances_num, solver_2approx_runtime_cpu, linestyle='-', color='r', alpha=0.5, zorder=2)
plt.plot(solver_instances_num, solver_christ_runtime_cpu, linestyle='-', color='g', alpha=0.5, zorder=2)

plt.xlabel('Problem Size (Vertices)')
plt.ylabel('CPU Time (s)')
plt.title('CPU Time TSP-Solvers')

plt.grid(True, linestyle='--', linewidth=0.5, zorder=1)
plt.xscale('log')
plt.legend()
plt.show()

# %%
# Scatter plot for better visualization
plt.figure(figsize=(12, 6))

# NN
# Plot completed instances
completed_indices = [i for i in range(len(solver_nn_status)) if solver_nn_status[i] == 'done']
plt.scatter(
    [solver_instances_num[i] for i in completed_indices],
    [solver_nn_runtime_wall[i] for i in completed_indices],
    color='k', label='NN (done)', zorder=3, marker='^'
)

# Plot aborted instances
aborted_indices = [i for i in range(len(solver_nn_status)) if solver_nn_status[i] == 'ABORTED']
plt.scatter(
    [solver_instances_num[i] for i in aborted_indices],
    [solver_nn_runtime_wall[i] for i in aborted_indices],
    color='k', label='NN (aborted)', zorder=3, marker='x'
)


# 2-Opt
# Plot completed instances
completed_indices = [i for i in range(len(solver_2opt_status)) if solver_2opt_status[i] == 'done']
plt.scatter(
    [solver_instances_num[i] for i in completed_indices],
    [solver_2opt_runtime_wall[i] for i in completed_indices],
    color='b', label='2-Opt (done)', zorder=3, marker='^'
)

# Plot aborted instances
aborted_indices = [i for i in range(len(solver_2opt_status)) if solver_2opt_status[i] == 'ABORTED']
plt.scatter(
    [solver_instances_num[i] for i in aborted_indices],
    [solver_2opt_runtime_wall[i] for i in aborted_indices],
    color='b', label='2-Opt (aborted)', zorder=3, marker='x'
)


# 2-Approx
# Plot completed instances
completed_indices = [i for i in range(len(solver_2approx_status)) if solver_2approx_status[i] == 'done']
plt.scatter(
    [solver_instances_num[i] for i in completed_indices],
    [solver_2approx_runtime_wall[i] for i in completed_indices],
    color='r', label='2-Approx (done)', zorder=3, marker='^'
)

# Plot aborted instances
aborted_indices = [i for i in range(len(solver_2approx_status)) if solver_2approx_status[i] == 'ABORTED']
plt.scatter(
    [solver_instances_num[i] for i in aborted_indices],
    [solver_2approx_runtime_wall[i] for i in aborted_indices],
    color='r', label='2-Approx (aborted)', zorder=3, marker='x'
)


# Christofides
# Plot completed instances
completed_indices = [i for i in range(len(solver_christ_status)) if solver_christ_status[i] == 'done']
plt.scatter(
    [solver_instances_num[i] for i in completed_indices],
    [solver_christ_runtime_wall[i] for i in completed_indices],
    color='g', label='Christofides (done)', zorder=3, marker='^'
)

# Plot aborted instances
aborted_indices = [i for i in range(len(solver_christ_status)) if solver_christ_status[i] == 'ABORTED']
plt.scatter(
    [solver_instances_num[i] for i in aborted_indices],
    [solver_christ_runtime_wall[i] for i in aborted_indices],
    color='g', label='Christofides (aborted)', zorder=3, marker='x'
)


plt.plot(solver_instances_num, solver_nn_runtime_wall, linestyle='-', color='k', alpha=0.5, zorder=2)
plt.plot(solver_instances_num, solver_2opt_runtime_wall, linestyle='-', color='b', alpha=0.5, zorder=2)
plt.plot(solver_instances_num, solver_2approx_runtime_wall, linestyle='-', color='r', alpha=0.5, zorder=2)
plt.plot(solver_instances_num, solver_christ_runtime_wall, linestyle='-', color='g', alpha=0.5, zorder=2)

plt.xlabel('Problem Size (Vertices)')
plt.ylabel('Wall Time (s)')
plt.title('Wall Time TSP-Solvers')

# Adjust x-axis labels
plt.xticks(rotation=90)

plt.grid(True, linestyle='--', linewidth=0.5, zorder=1)
plt.xscale('log')
plt.legend()
plt.show()

# %%
# Scatter plot for better visualization
plt.figure(figsize=(12, 6))

# NN
# Plot completed instances
completed_indices = [i for i in range(len(solver_nn_status)) if solver_nn_status[i] == 'done']
plt.scatter(
    [solver_instances_num[i] for i in completed_indices],
    [solver_nn_memory[i] for i in completed_indices],
    color='k', label='NN (done)', zorder=3, marker='^'
)

# Plot aborted instances
aborted_indices = [i for i in range(len(solver_nn_status)) if solver_nn_status[i] == 'ABORTED']
plt.scatter(
    [solver_instances_num[i] for i in aborted_indices],
    [solver_nn_memory[i] for i in aborted_indices],
    color='k', label='NN (aborted)', zorder=3, marker='x'
)


# 2-Opt
# Plot completed instances
completed_indices = [i for i in range(len(solver_2opt_status)) if solver_2opt_status[i] == 'done']
plt.scatter(
    [solver_instances_num[i] for i in completed_indices],
    [solver_2opt_memory[i] for i in completed_indices],
    color='b', label='2-Opt (done)', zorder=3, marker='^'
)

# Plot aborted instances
aborted_indices = [i for i in range(len(solver_2opt_status)) if solver_2opt_status[i] == 'ABORTED']
plt.scatter(
    [solver_instances_num[i] for i in aborted_indices],
    [solver_2opt_memory[i] for i in aborted_indices],
    color='b', label='2-Opt (aborted)', zorder=3, marker='x'
)


# 2-Approx
# Plot completed instances
completed_indices = [i for i in range(len(solver_2approx_status)) if solver_2approx_status[i] == 'done']
plt.scatter(
    [solver_instances_num[i] for i in completed_indices],
    [solver_2approx_memory[i] for i in completed_indices],
    color='r', label='2-Approx (done)', zorder=3, marker='^'
)

# Plot aborted instances
aborted_indices = [i for i in range(len(solver_2approx_status)) if solver_2approx_status[i] == 'ABORTED']
plt.scatter(
    [solver_instances_num[i] for i in aborted_indices],
    [solver_2approx_memory[i] for i in aborted_indices],
    color='r', label='2-Approx (aborted)', zorder=3, marker='x'
)


# Christofides
# Plot completed instances
completed_indices = [i for i in range(len(solver_christ_status)) if solver_christ_status[i] == 'done']
plt.scatter(
    [solver_instances_num[i] for i in completed_indices],
    [solver_christ_memory[i] for i in completed_indices],
    color='g', label='Christofides (done)', zorder=3, marker='^'
)

# Plot aborted instances
aborted_indices = [i for i in range(len(solver_christ_status)) if solver_christ_status[i] == 'ABORTED']
plt.scatter(
    [solver_instances_num[i] for i in aborted_indices],
    [solver_christ_memory[i] for i in aborted_indices],
    color='g', label='Christofides (aborted)', zorder=3, marker='x'
)

plt.plot(solver_instances_num, solver_nn_memory, linestyle='-', color='k', alpha=0.5, zorder=2)
plt.plot(solver_instances_num, solver_2opt_memory, linestyle='-', color='b', alpha=0.5, zorder=2)
plt.plot(solver_instances_num, solver_2approx_memory, linestyle='-', color='r', alpha=0.5, zorder=2)
plt.plot(solver_instances_num, solver_christ_memory, linestyle='-', color='g', alpha=0.5, zorder=2)

plt.xlabel('Problem Size (Vertices)')
plt.ylabel('Memory (MB)')
plt.title('Memory Consumption TSP-Solvers')

plt.grid(True, linestyle='--', linewidth=0.5, zorder=1)
plt.xscale('log')
plt.legend()
plt.show()
