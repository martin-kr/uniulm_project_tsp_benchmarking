# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

# %%
exclude_pla33810 = True

# %%
# small 
optimal_eil51   = 426
optimal_st70    = 675
optimal_kroA100 = 21282
optimal_pr144   = 58537
optimal_ts225   = 126643
optimal_a280    = 2579
optimal_pr299   = 48191
optimal_pr439   = 107217
optimal_pcb442  = 50778
optimal_d493    = 35002

optimal_rat575  = 6773
optimal_d657    = 48912
optimal_u724    = 41910
optimal_dsj1000 = 18660188
optimal_pr1002  = 259045
optimal_rl1304  = 252948
optimal_nrw1379 = 56638
optimal_u1432   = 152970
optimal_vm1748  = 336556
optimal_u1817   = 57201

optimal_u2319    = 234256
optimal_pcb3038  = 137694
optimal_fl3795   = 28772
optimal_fnl4461  = 182566
optimal_rl5915   = 565530
optimal_pla7397  = 23260728
optimal_rl11849  = 923288
optimal_brd14051 = 469385
optimal_d18512   = 645238
optimal_pla33810 = 66048945

# %%
solver_nn_eil51   = 511
solver_nn_st70    = 830
solver_nn_kroA100 = 27807
solver_nn_pr144   = 61652
solver_nn_ts225   = 152493
solver_nn_a280    = 3157
solver_nn_pr299   = 59890
solver_nn_pr439   = 131281
solver_nn_pcb442  = 61979
solver_nn_d493    = 41666

solver_nn_rat575  = 8605
solver_nn_d657    = 61627
solver_nn_u724    = 52943
solver_nn_dsj1000 = 24631468
solver_nn_pr1002  = 331103
solver_nn_rl1304  = 335779
solver_nn_nrw1379 = 68964
solver_nn_u1432   = 188807
solver_nn_vm1748  = 408102
solver_nn_u1817   = 72030

solver_nn_u2319    = 278765
solver_nn_pcb3038  = 176310
solver_nn_fl3795   = 35285
solver_nn_fnl4461  = 229963
solver_nn_rl5915   = 695602
solver_nn_pla7397  = 28107289
solver_nn_rl11849  = 1125249
solver_nn_brd14051 = 585382 
solver_nn_d18512   = 799220
solver_nn_pla33810 = 77332499

# %%
solver_2opt_eil51   = 470
solver_2opt_st70    = 766
solver_2opt_kroA100 = 23183
solver_2opt_pr144   = 62383
solver_2opt_ts225   = 143198
solver_2opt_a280    = 2772
solver_2opt_pr299   = 52052
solver_2opt_pr439   = 112550
solver_2opt_pcb442  = 57119
solver_2opt_d493    = 37829

solver_2opt_rat575  = 7611
solver_2opt_d657    = 55143
solver_2opt_u724    = 46863
solver_2opt_dsj1000 = 20795859
solver_2opt_pr1002  = 280631
solver_2opt_rl1304  = 296380
solver_2opt_nrw1379 = 62894
solver_2opt_u1432   = 169575
solver_2opt_vm1748  = 379813
solver_2opt_u1817   = 65378

solver_2opt_u2319    = 256803
solver_2opt_pcb3038  = 154629
solver_2opt_fl3795   = 30877
solver_2opt_fnl4461  = 205280
solver_2opt_rl5915   = 652286
solver_2opt_pla7397  = 26522176
solver_2opt_rl11849  = 1060909
solver_2opt_brd14051 = 529246 
solver_2opt_d18512   = 724900
solver_2opt_pla33810 = 73989323

# %%
solver_2approx_eil51   = 609
solver_2approx_st70    = 884
solver_2approx_kroA100 = 29427
solver_2approx_pr144   = 83967
solver_2approx_ts225   = 200412
solver_2approx_a280    = 3898
solver_2approx_pr299   = 66207
solver_2approx_pr439   = 147085 
solver_2approx_pcb442  = 78869
solver_2approx_d493    = 48224

solver_2approx_rat575  = 9867
solver_2approx_d657    = 68307
solver_2approx_u724    = 60873
solver_2approx_dsj1000 = 25771732
solver_2approx_pr1002  = 364651
solver_2approx_rl1304  = 391813
solver_2approx_nrw1379 = 80769
solver_2approx_u1432   = 233700 
solver_2approx_vm1748  = 491440
solver_2approx_u1817   = 89436

solver_2approx_u2319    = 366703
solver_2approx_pcb3038  = 199032
solver_2approx_fl3795   = 43928
solver_2approx_fnl4461  = 260843
solver_2approx_rl5915   = 880510
solver_2approx_pla7397  = 36499374
solver_2approx_rl11849  = 1422133
solver_2approx_brd14051 = 675052
solver_2approx_d18512   = 927808
solver_2approx_pla33810 = 0

# %%
solver_christ_eil51   = 515
solver_christ_st70    = 806
solver_christ_kroA100 = 26698
solver_christ_pr144   = 73356
solver_christ_ts225   = 143506
solver_christ_a280    = 3342
solver_christ_pr299   = 64248
solver_christ_pr439   = 131765
solver_christ_pcb442  = 69481
solver_christ_d493    = 44189

solver_christ_rat575  = 9501
solver_christ_d657    = 65508
solver_christ_u724    = 55767
solver_christ_dsj1000 = 24840622
solver_christ_pr1002  = 350207
solver_christ_rl1304  = 302083
solver_christ_nrw1379 = 77579
solver_christ_u1432   = 204507
solver_christ_vm1748  = 441300
solver_christ_u1817   = 74295

solver_christ_u2319    = 337996
solver_christ_pcb3038  = 182354
solver_christ_fl3795   = 41907
solver_christ_fnl4461  = 251413
solver_christ_rl5915   = 745927
solver_christ_pla7397  = 31114504
solver_christ_rl11849  = 1208737
solver_christ_brd14051 = 644815 
solver_christ_d18512   = 872083
solver_christ_pla33810 = 0

# %%
# start analysis
if exclude_pla33810 == False:
    optimal_array = [
        optimal_eil51, optimal_st70, optimal_kroA100, optimal_pr144,
        optimal_ts225, optimal_a280, optimal_pr299, optimal_pr439,
        optimal_pcb442, optimal_d493, optimal_rat575, optimal_d657,
        optimal_u724, optimal_dsj1000, optimal_pr1002, optimal_rl1304,
        optimal_nrw1379, optimal_u1432, optimal_vm1748, optimal_u1817,
        optimal_u2319, optimal_pcb3038, optimal_fl3795, optimal_fnl4461,
        optimal_rl5915, optimal_pla7397, optimal_rl11849, optimal_brd14051,
        optimal_d18512, optimal_pla33810
    ]

    solver_nn_array = [
        solver_nn_eil51, solver_nn_st70, solver_nn_kroA100, solver_nn_pr144,
        solver_nn_ts225, solver_nn_a280, solver_nn_pr299, solver_nn_pr439,
        solver_nn_pcb442, solver_nn_d493, solver_nn_rat575, solver_nn_d657,
        solver_nn_u724, solver_nn_dsj1000, solver_nn_pr1002, solver_nn_rl1304,
        solver_nn_nrw1379, solver_nn_u1432, solver_nn_vm1748, solver_nn_u1817,
        solver_nn_u2319, solver_nn_pcb3038, solver_nn_fl3795, solver_nn_fnl4461,
        solver_nn_rl5915, solver_nn_pla7397, solver_nn_rl11849, solver_nn_brd14051,
        solver_nn_d18512, solver_nn_pla33810
    ]

    solver_2opt_array = [
        solver_2opt_eil51, solver_2opt_st70, solver_2opt_kroA100, solver_2opt_pr144,
        solver_2opt_ts225, solver_2opt_a280, solver_2opt_pr299, solver_2opt_pr439,
        solver_2opt_pcb442, solver_2opt_d493, solver_2opt_rat575, solver_2opt_d657,
        solver_2opt_u724, solver_2opt_dsj1000, solver_2opt_pr1002, solver_2opt_rl1304,
        solver_2opt_nrw1379, solver_2opt_u1432, solver_2opt_vm1748, solver_2opt_u1817,
        solver_2opt_u2319, solver_2opt_pcb3038, solver_2opt_fl3795, solver_2opt_fnl4461,
        solver_2opt_rl5915, solver_2opt_pla7397, solver_2opt_rl11849, solver_2opt_brd14051,
        solver_2opt_d18512, solver_2opt_pla33810
    ]

    solver_2approx_array = [
        solver_2approx_eil51, solver_2approx_st70, solver_2approx_kroA100, solver_2approx_pr144,
        solver_2approx_ts225, solver_2approx_a280, solver_2approx_pr299, solver_2approx_pr439,
        solver_2approx_pcb442, solver_2approx_d493, solver_2approx_rat575, solver_2approx_d657,
        solver_2approx_u724, solver_2approx_dsj1000, solver_2approx_pr1002, solver_2approx_rl1304,
        solver_2approx_nrw1379, solver_2approx_u1432, solver_2approx_vm1748, solver_2approx_u1817,
        solver_2approx_u2319, solver_2approx_pcb3038, solver_2approx_fl3795, solver_2approx_fnl4461,
        solver_2approx_rl5915, solver_2approx_pla7397, solver_2approx_rl11849, solver_2approx_brd14051,
        solver_2approx_d18512, solver_2approx_pla33810
    ]

    solver_christ_array = [
        solver_christ_eil51, solver_christ_st70, solver_christ_kroA100, solver_christ_pr144,
        solver_christ_ts225, solver_christ_a280, solver_christ_pr299, solver_christ_pr439,
        solver_christ_pcb442, solver_christ_d493, solver_christ_rat575, solver_christ_d657,
        solver_christ_u724, solver_christ_dsj1000, solver_christ_pr1002, solver_christ_rl1304,
        solver_christ_nrw1379, solver_christ_u1432, solver_christ_vm1748, solver_christ_u1817,
        solver_christ_u2319, solver_christ_pcb3038, solver_christ_fl3795, solver_christ_fnl4461,
        solver_christ_rl5915, solver_christ_pla7397, solver_christ_rl11849, solver_christ_brd14051,
        solver_christ_d18512, solver_christ_pla33810
    ]

    instance_names = [
        "eil51", "st70", "kroA100", "pr144", "ts225", "a280", "pr299", "pr439",
        "pcb442", "d493", "rat575", "d657", "u724", "dsj1000", "pr1002", "rl1304",
        "nrw1379", "u1432", "vm1748", "u1817", "u2319", "pcb3038", "fl3795", "fnl4461",
        "rl5915", "pla7397", "rl11849", "brd14051", "d18512", "pla33810"
    ]

else:
    optimal_array = [
        optimal_eil51, optimal_st70, optimal_kroA100, optimal_pr144,
        optimal_ts225, optimal_a280, optimal_pr299, optimal_pr439,
        optimal_pcb442, optimal_d493, optimal_rat575, optimal_d657,
        optimal_u724, optimal_dsj1000, optimal_pr1002, optimal_rl1304,
        optimal_nrw1379, optimal_u1432, optimal_vm1748, optimal_u1817,
        optimal_u2319, optimal_pcb3038, optimal_fl3795, optimal_fnl4461,
        optimal_rl5915, optimal_pla7397, optimal_rl11849, optimal_brd14051,
        optimal_d18512
    ]
    
    solver_nn_array = [
        solver_nn_eil51, solver_nn_st70, solver_nn_kroA100, solver_nn_pr144,
        solver_nn_ts225, solver_nn_a280, solver_nn_pr299, solver_nn_pr439,
        solver_nn_pcb442, solver_nn_d493, solver_nn_rat575, solver_nn_d657,
        solver_nn_u724, solver_nn_dsj1000, solver_nn_pr1002, solver_nn_rl1304,
        solver_nn_nrw1379, solver_nn_u1432, solver_nn_vm1748, solver_nn_u1817,
        solver_nn_u2319, solver_nn_pcb3038, solver_nn_fl3795, solver_nn_fnl4461,
        solver_nn_rl5915, solver_nn_pla7397, solver_nn_rl11849, solver_nn_brd14051,
        solver_nn_d18512
    ]
    
    solver_2opt_array = [
        solver_2opt_eil51, solver_2opt_st70, solver_2opt_kroA100, solver_2opt_pr144,
        solver_2opt_ts225, solver_2opt_a280, solver_2opt_pr299, solver_2opt_pr439,
        solver_2opt_pcb442, solver_2opt_d493, solver_2opt_rat575, solver_2opt_d657,
        solver_2opt_u724, solver_2opt_dsj1000, solver_2opt_pr1002, solver_2opt_rl1304,
        solver_2opt_nrw1379, solver_2opt_u1432, solver_2opt_vm1748, solver_2opt_u1817,
        solver_2opt_u2319, solver_2opt_pcb3038, solver_2opt_fl3795, solver_2opt_fnl4461,
        solver_2opt_rl5915, solver_2opt_pla7397, solver_2opt_rl11849, solver_2opt_brd14051,
        solver_2opt_d18512
    ]
    
    solver_2approx_array = [
        solver_2approx_eil51, solver_2approx_st70, solver_2approx_kroA100, solver_2approx_pr144,
        solver_2approx_ts225, solver_2approx_a280, solver_2approx_pr299, solver_2approx_pr439,
        solver_2approx_pcb442, solver_2approx_d493, solver_2approx_rat575, solver_2approx_d657,
        solver_2approx_u724, solver_2approx_dsj1000, solver_2approx_pr1002, solver_2approx_rl1304,
        solver_2approx_nrw1379, solver_2approx_u1432, solver_2approx_vm1748, solver_2approx_u1817,
        solver_2approx_u2319, solver_2approx_pcb3038, solver_2approx_fl3795, solver_2approx_fnl4461,
        solver_2approx_rl5915, solver_2approx_pla7397, solver_2approx_rl11849, solver_2approx_brd14051,
        solver_2approx_d18512
    ]
    
    solver_christ_array = [
        solver_christ_eil51, solver_christ_st70, solver_christ_kroA100, solver_christ_pr144,
        solver_christ_ts225, solver_christ_a280, solver_christ_pr299, solver_christ_pr439,
        solver_christ_pcb442, solver_christ_d493, solver_christ_rat575, solver_christ_d657,
        solver_christ_u724, solver_christ_dsj1000, solver_christ_pr1002, solver_christ_rl1304,
        solver_christ_nrw1379, solver_christ_u1432, solver_christ_vm1748, solver_christ_u1817,
        solver_christ_u2319, solver_christ_pcb3038, solver_christ_fl3795, solver_christ_fnl4461,
        solver_christ_rl5915, solver_christ_pla7397, solver_christ_rl11849, solver_christ_brd14051,
        solver_christ_d18512
    ]
    
    instance_names = [
        "eil51", "st70", "kroA100", "pr144", "ts225", "a280", "pr299", "pr439",
        "pcb442", "d493", "rat575", "d657", "u724", "dsj1000", "pr1002", "rl1304",
        "nrw1379", "u1432", "vm1748", "u1817", "u2319", "pcb3038", "fl3795", "fnl4461",
        "rl5915", "pla7397", "rl11849", "brd14051", "d18512"
    ]

# %%
# Calculate the absolute error
abs_error_solver_nn = np.abs(np.array(optimal_array) - np.array(solver_nn_array))
abs_error_solver_2opt = np.abs(np.array(optimal_array) - np.array(solver_2opt_array))
abs_error_solver_2approx = np.abs(np.array(optimal_array) - np.array(solver_2approx_array))
abs_error_solver_christ = np.abs(np.array(optimal_array) - np.array(solver_christ_array))

# Calculate the relative error
relative_error_solver_nn = (abs_error_solver_nn / np.array(optimal_array)) * 100
relative_error_solver_2opt = (abs_error_solver_2opt / np.array(optimal_array)) * 100
relative_error_solver_2approx = (abs_error_solver_2approx / np.array(optimal_array)) * 100
relative_error_solver_christ = (abs_error_solver_christ / np.array(optimal_array)) * 100

# %%
relative_error_solver_nn
# Out:
# array([19.95305164, 22.96296296, 30.65971243,  5.32142064, 20.4117085 ,
#        22.41178751, 24.27631715, 22.44420195, 22.05876561, 19.03891206,
#        27.04857523, 25.99566569, 26.32545932, 32.00010632, 27.81678859,
#        32.74625615, 21.76277411, 23.42746944, 21.258275  , 25.92437195,
#        19.00015368, 28.04479498, 22.63659113, 25.96157006, 23.00001768,
#        20.83580961, 21.87410645, 24.7125494 , 23.86437253])

# %%
relative_error_solver_2opt
# Out:
# array([10.3286385 , 13.48148148,  8.93243116,  6.57020346, 13.07217928,
#         7.48352074,  8.01186944,  4.97402464, 12.48769152,  8.07668133,
#        12.37265613, 12.7392051 , 11.81818182, 11.4450669 ,  8.33291513,
#        17.1703275 , 11.04558777, 10.85506962, 12.85283875, 14.29520463,
#         9.62494024, 12.29901085,  7.31614069, 12.441528  , 15.3406539 ,
#        14.02126365, 14.90553327, 12.75307051, 12.34614204])

# %%
relative_error_solver_2approx
# Out:
# array([42.95774648, 30.96296296, 38.27177897, 43.44260895, 58.24956768,
#        51.14385421, 37.38457388, 37.18440173, 55.3212021 , 37.77498429,
#        45.68138196, 39.65284593, 45.24695777, 38.11078431, 40.76743423,
#        54.89863529, 42.6056711 , 52.77505393, 46.02027597, 56.3539099 ,
#        56.53942695, 44.54660334, 52.67621298, 42.87600101, 55.69642636,
#        56.91415161, 54.02918699, 43.81627023, 43.793143  ])

# %%
relative_error_solver_christ
# Out:
# array([20.89201878, 19.40740741, 25.44873602, 25.31561235, 13.31538261,
#        29.58511051, 33.31949949, 22.8956229 , 36.83288038, 26.2470716 ,
#        40.27757272, 33.93032385, 33.06370795, 33.1209632 , 35.19156903,
#        19.42494109, 36.97341008, 33.69091979, 31.12230951, 29.88409294,
#        44.28488491, 32.43423824, 45.6520228 , 37.7107457 , 31.89874985,
#        33.76410231, 30.91657208, 37.37443676, 35.15679486])

# %%
# Calculate the mean relative error for each solver
mean_relative_error_solver_nn = np.mean(relative_error_solver_nn)
mean_relative_error_solver_2opt = np.mean(relative_error_solver_2opt)
mean_relative_error_solver_2approx = np.mean(relative_error_solver_2approx)
mean_relative_error_solver_christ = np.mean(relative_error_solver_christ)

# Display the mean relative errors
mean_relative_error_solver_nn, mean_relative_error_solver_2opt, mean_relative_error_solver_2approx, mean_relative_error_solver_christ
# Out:
# (np.float64(23.578432681857542),
#  np.float64(11.289450277713442),
#  np.float64(46.40324324467097),
#  np.float64(31.34936895483592))

# %%
# Calculate the variance of the relative error for each solver
variance_relative_error_solver_nn = np.var(relative_error_solver_nn)
variance_relative_error_solver_2opt = np.var(relative_error_solver_2opt)
variance_relative_error_solver_2approx = np.var(relative_error_solver_2approx)
variance_relative_error_solver_christ = np.var(relative_error_solver_christ)

# Display the variances
variance_relative_error_solver_nn, variance_relative_error_solver_2opt, variance_relative_error_solver_2approx, variance_relative_error_solver_christ
# Out:
# (np.float64(24.318742132473986),
#  np.float64(8.046510329441233),
#  np.float64(55.48486500414592),
#  np.float64(53.1844866974141))

# %%
# Create the plot
plt.figure(figsize=(10, 6))

# Plot relative errors for each solver
plt.plot(instance_names, relative_error_solver_nn, label='Solver NN', marker='o')
plt.plot(instance_names, relative_error_solver_2opt, label='Solver 2-Opt', marker='o')
plt.plot(instance_names, relative_error_solver_2approx, label='Solver 2-Approx', marker='o')
plt.plot(instance_names, relative_error_solver_christ, label='Solver Christ', marker='o')

# Add labels and title
plt.xlabel('Instance')
plt.ylabel('Relative Error (%)')
plt.title('Relative Error for Different Solvers')
plt.legend()

# Show the plot
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
